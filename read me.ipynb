# %% [markdown]
# # 📊 Shopify Sales & Funnel Report | Power BI Dashboard
#
# This Power BI project presents an interactive sales and funnel analysis dashboard for a Shopify-based e-commerce business. It provides end-to-end visibility into key performance metrics across geography, time, products, and payment gateways — enabling actionable business decisions through data visualization.
#
# ---
#
# ## 🔍 Project Summary
#
# - **Project Title:** Shopify Sales & Funnel Analysis
# - **Tool Used:** Power BI
# - **Dataset:** Shopify sales transaction data (mock dataset used for visualization)
# - **Pages Included:**
#   - Main Dashboard: `Shopify Analysis`
#   - Raw Data View: `Database`
#
# ---
#
# ## 📌 Business Objectives
#
# - Analyze total sales performance across time, city, and states.
# - Monitor product-wise revenue distribution.
# - Identify best-performing cities and payment methods.
# - Track hourly and daily sales trends to optimize operations.
# - Enable interactive drilldown for deeper insight using slicers and filters.
#
# ---
#
# ## 🧠 Key Insights (Business Outcomes)
#
# - 🟢 **Total Net Sales:** $41.8M, indicating strong market performance.
# - 🟢 **Average Order Value:** $562.6, showing high-value transactions.
# - 🟢 **High-Performing Cities:** Washington, Houston, New York.
# - 🟢 **Best Gateway:** Shopify Payments (58.45% of revenue).
# - 🟢 **Top-Selling Product Categories:** Cell Phones, Laptops, Accessories.
# - 🟢 **Peak Activity Hours:** Between 10 AM to 4 PM.
# - 🟢 **Geographical Focus:** Eastern & Southern U.S. show highest customer density.
#
# ---
#
# ## 📈 Features of Dashboard
#
# - KPI Cards for quick snapshot of performance.
# - Interactive Slicers (Date, Gateway, Measure).
# - Geographical Map (Net Sales by Location).
# - Bar and Line Charts (Sales by Hour, Day, City, Product Type).
# - Pie Chart for Gateway-wise Revenue.
# - Dynamic Filtering using radio buttons for measure selection.
#
# ---
#
# ## 🧰 Tools & Technologies
#
# - **Power BI Desktop** (Data Modeling + DAX Calculations)
# - **Custom Visuals** (Map, Slicer, Line Chart, Pie Chart)
# - **Data Cleaning & Transformation** (Power Query)
# - **UI/UX Optimization** (Color Themes, Layout Design)
#
# ---
#
# ## 🗂 Files Included
#
# | File Name                 | Description                                    |
# |--------------------------|------------------------------------------------|
# | `shopify_sales_report.pbix` | Power BI file with visuals and dataset       |
# | `README.md`              | Documentation and project summary              |
# | `Database Page` (in PBIX) | Contains raw dataset used for analysis         |
#
# ---
#
# ## 🚀 How to Use
#
# 1. Download the `.pbix` file from the repository.
# 2. Open with **Power BI Desktop**.
# 3. Explore interactive filters and visuals.
# 4. Go to `Database` tab to view the raw data (no external Excel required).
#
# ---
#
# ## 📬 Contact
#
# For any feedback or queries, feel free to connect via GitHub or email.
# ### EMAIL : riyadew77@gmail.com
#
#
# ---
